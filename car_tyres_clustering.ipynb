# %%
import pandas as pd
import numpy as np

# NLP
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# Clustering
from sklearn.cluster import KMeans

# Visualization
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("Car_Tyres_Dataset.csv")
df.head()
# Out:
#    Brand         Model      Submodel  ... Selling Price Original Price Rating
# 0  Maruti  Swift Dzire  LDI (Diesel)  ...         3,255          3,255    5.0
# 1  Maruti  Swift Dzire  LDI (Diesel)  ...         3,406          3,406    4.0
# 2  Maruti  Swift Dzire  LDI (Diesel)  ...         3,490          4,319    4.5
# 3  Maruti  Swift Dzire  LDI (Diesel)  ...         4,484          4,244    NaN
# 4  Maruti  Swift Dzire  LDI (Diesel)  ...         3,025          3,025    4.2
#
# [5 rows x 11 columns]

# %%
def preprocess_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    words = text.split()
    words = [word for word in words if word not in stop_words]
    return " ".join(words)

# %%
for col in df.columns:
    print(f"'{col}'")
# Out:
# 'Brand '
# 'Model'
# 'Submodel'
# 'Tyre Brand'
# 'Serial No.'
# 'Type'
# 'Load Index'
# 'Size'
# 'Selling Price'
# 'Original Price'
# 'Rating'

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns)
# Out:
# Index(['brand', 'model', 'submodel', 'tyre_brand', 'serial_no.', 'type',
#        'load_index', 'size', 'selling_price', 'original_price', 'rating'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['brand', 'model', 'submodel', 'tyre_brand', 'serial_no.', 'type',
#        'load_index', 'size', 'selling_price', 'original_price', 'rating'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['brand', 'model', 'submodel', 'tyre_brand', 'serial_no.', 'type',
#        'load_index', 'size', 'selling_price', 'original_price', 'rating'],
#       dtype='str')

# %%
print([col for col in df.columns])
# Out:
# ['brand', 'model', 'submodel', 'tyre_brand', 'serial_no.', 'type', 'load_index', 'size', 'selling_price', 'original_price', 'rating']

# %%
if 'Cluster' not in df.columns:
    print("Cluster column not found!")
# Out:
# Cluster column not found!

# %%
print("Columns:", df.columns)

if 'Cluster' not in df.columns:
    print("❌ Cluster column is missing")
else:
    print("✅ Cluster column exists")
# Out:
# Columns: Index(['brand', 'model', 'submodel', 'tyre_brand', 'serial_no.', 'type',
#        'load_index', 'size', 'selling_price', 'original_price', 'rating'],
#       dtype='str')
# ❌ Cluster column is missing
