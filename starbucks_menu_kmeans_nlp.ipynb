# %%
import pandas as pd
import numpy as np

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

# Vectorization
from sklearn.feature_extraction.text import TfidfVectorizer

# Clustering
from sklearn.cluster import KMeans

# Visualization
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv("star_menu_scrubbed.csv")

# Preview
df.head()
# Out:
#          beverage_category   product_name      beverage_prep  calories  fat_g  \
# 0                   Coffee  Brewed Coffee              Short         3    0.1
# 1                   Coffee  Brewed Coffee               Tall         4    0.1
# 2                   Coffee  Brewed Coffee             Grande         5    0.1
# 3                   Coffee  Brewed Coffee              Venti         5    0.1
# 4  Classic Espresso Drinks    Caffè Latte  Short Nonfat Milk        70    0.1
#
#    carbohydrates_g  proteins_g
# 0              5.0         0.3
# 1             10.0         0.5
# 2             10.0         1.0
# 3             10.0         1.0
# 4             75.0         6.0

# %%
df.head()
df.columns
# Out:
# Index(['beverage_category', 'product_name', 'beverage_prep', 'calories',
#        'fat_g', 'carbohydrates_g', 'proteins_g'],
#       dtype='str')

# %%
print(df.columns)              # Check names
df.columns = df.columns.str.strip()  # Remove hidden spaces
print(df.head())              # Inspect data
# Out:
# Index(['beverage_category', 'product_name', 'beverage_prep', 'calories',
#        'fat_g', 'carbohydrates_g', 'proteins_g'],
#       dtype='str')
#          beverage_category   product_name      beverage_prep  calories  fat_g  \
# 0                   Coffee  Brewed Coffee              Short         3    0.1
# 1                   Coffee  Brewed Coffee               Tall         4    0.1
# 2                   Coffee  Brewed Coffee             Grande         5    0.1
# 3                   Coffee  Brewed Coffee              Venti         5    0.1
# 4  Classic Espresso Drinks    Caffè Latte  Short Nonfat Milk        70    0.1
#
#    carbohydrates_g  proteins_g
# 0              5.0         0.3
# 1             10.0         0.5
# 2             10.0         1.0
# 3             10.0         1.0
# 4             75.0         6.0

# %%
import numpy as np

X = np.array([
    [1, 2],
    [3, 4],
    [5, 6]
])

# %%
print(X.shape)
print(df.shape)
# Out:
# (3, 2)
# (242, 7)

# %%
print(documents)
print(type(documents))
# Out:
# [Ellipsis]
# <class 'list'>

# %%
df.to_csv("clustered_starbucks_menu.csv", index=False)
