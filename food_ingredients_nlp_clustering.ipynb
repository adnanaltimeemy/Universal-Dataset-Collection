# %%
import pandas as pd
import numpy as np

# NLP
import re
import nltk
from nltk.corpus import stopwords

# Vectorization
from sklearn.feature_extraction.text import TfidfVectorizer

# Clustering
from sklearn.cluster import KMeans

# Visualization
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("world_food_scrubbed.csv")

# Preview
df.head()
# Out:
#                    product_name        packaging  ... fp_lon contains_additives
# 0                  Salade Cesar            frais  ...  -2.67                  0
# 1  Chaussons tressés aux pommes            frais  ...  -2.67                  1
# 2           Pain Burger Artisan  frais,plastique  ...  -2.67                  0
# 3                     Root Beer    canette,métal  ...  -2.67                  1
# 4               Quiche Lorraine             frai  ...  -2.67                  1
#
# [5 rows x 13 columns]

# %%
if 'ingredients' in df.columns:
    df = df.dropna(subset=['ingredients'])

# %%
print(df.head())
# Out:
#                    product_name        packaging  ... fp_lon contains_additives
# 0                  Salade Cesar            frais  ...  -2.67                  0
# 1  Chaussons tressés aux pommes            frais  ...  -2.67                  1
# 2           Pain Burger Artisan  frais,plastique  ...  -2.67                  0
# 3                     Root Beer    canette,métal  ...  -2.67                  1
# 4               Quiche Lorraine             frai  ...  -2.67                  1
#
# [5 rows x 13 columns]

# %%
print(df.columns.tolist())
# Out:
# ['product_name', 'packaging', 'main_category', 'nutrition_grade_fr', 'nutrition_score', 'fat_g', 'carbohydrates_g', 'proteins_g', 'additives_n', 'ingredients_from_palm_oil_n', 'fp_lat', 'fp_lon', 'contains_additives']

# %%
print(df.columns)
# Out:
# Index(['product_name', 'packaging', 'main_category', 'nutrition_grade_fr',
#        'nutrition_score', 'fat_g', 'carbohydrates_g', 'proteins_g',
#        'additives_n', 'ingredients_from_palm_oil_n', 'fp_lat', 'fp_lon',
#        'contains_additives'],
#       dtype='str')

# %%
for col in ['ingredients', 'cluster']:
    print(col, col in df.columns)
# Out:
# ingredients False
# cluster False

# %%
print(hasattr(vectorizer, "vocabulary_"))
# Out:
# False

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Change column name if needed
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df.iloc[:,0].astype(str))

# %%
df.to_csv("clustered_food_data.csv", index=False)
