# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("RestaurantFoods.csv")

df.head()
# Out:
#    Food ID   Food Item  Price
# 0        1       Sushi   3.99
# 1        2     Burrito   9.99
# 2        3        Taco   2.99
# 3        4  Quesadilla   4.25
# 4        5       Pizza   2.49

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'Food ID'
# 'Food Item'
# 'Price'

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns)
# Out:
# Index(['Food ID', 'Food Item', 'Price'], dtype='str')

# %%
print(df.head())
print(df.columns)
# Out:
#    Food ID   Food Item  Price
# 0        1       Sushi   3.99
# 1        2     Burrito   9.99
# 2        3        Taco   2.99
# 3        4  Quesadilla   4.25
# 4        5       Pizza   2.49
# Index(['Food ID', 'Food Item', 'Price'], dtype='str')

# %%
df.columns = df.columns.str.strip().str.title()

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns)
# Out:
# Index(['Food Id', 'Food Item', 'Price'], dtype='str')
